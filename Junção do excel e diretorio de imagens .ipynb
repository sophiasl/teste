# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
# Prepare 1st table (artworks-arquivo excel)

artworks = pd.read_csv(r'C:\Users\annes\OneDrive\Bureau\data\artists.csv')
artworks.dataframeName = 'artists.csv'
nRow, nCol = artworks.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 50 rows and 8 columns

# %%
artworks.head()
# Out:
#    id                name        years                         genre  \
# 0   0   Amedeo Modigliani  1884 - 1920                 Expressionism
# 1   1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism
# 2   2        Diego Rivera  1886 - 1957       Social Realism,Muralism
# 3   3        Claude Monet  1840 - 1926                 Impressionism
# 4   4       Rene Magritte  1898 - 1967      Surrealism,Impressionism
#
#   nationality                                                bio  \
# 0     Italian  Amedeo Clemente Modigliani (Italian pronunciat...
# 1     Russian  Wassily Wassilyevich Kandinsky (Russian: Васи́...
# 2     Mexican  Diego María de la Concepción Juan Nepomuceno E...
# 3      French  Oscar-Claude Monet (; French: [klod mɔnɛ]; 14 ...
# 4     Belgian  René François Ghislain Magritte (French: [ʁəne...
#
#                                         wikipedia  paintings
# 0  http://en.wikipedia.org/wiki/Amedeo_Modigliani        193
# 1  http://en.wikipedia.org/wiki/Wassily_Kandinsky         88
# 2       http://en.wikipedia.org/wiki/Diego_Rivera         70
# 3       http://en.wikipedia.org/wiki/Claude_Monet         73
# 4      http://en.wikipedia.org/wiki/René_Magritte        194

# %%
artworks_shrunk= artworks.drop(labels=['id','years','nationality','bio','wikipedia','paintings'],axis=1)
artworks_shrunk.head(2)
# Out:
#                  name                         genre
# 0   Amedeo Modigliani                 Expressionism
# 1  Vasiliy Kandinskiy  Expressionism,Abstractionism

# %%
artworks_shrunk[['genre_1','genre_2','genre_3']] = artworks_shrunk['genre'].str.split(",",expand=True)
artworks_shrunk
# Out:
#                          name                                    genre  \
# 0           Amedeo Modigliani                            Expressionism
# 1          Vasiliy Kandinskiy             Expressionism,Abstractionism
# 2                Diego Rivera                  Social Realism,Muralism
# 3                Claude Monet                            Impressionism
# 4               Rene Magritte                 Surrealism,Impressionism
# 5               Salvador Dali                               Surrealism
# 6               Edouard Manet                    Realism,Impressionism
# 7               Andrei Rublev                            Byzantine Art
# 8            Vincent van Gogh                       Post-Impressionism
# 9                Gustav Klimt                    Symbolism,Art Nouveau
# 10           Hieronymus Bosch                     Northern Renaissance
# 11           Kazimir Malevich                              Suprematism
# 12             Mikhail Vrubel                                Symbolism
# 13              Pablo Picasso                                   Cubism
# 14          Peter Paul Rubens                                  Baroque
# 15      Pierre-Auguste Renoir                            Impressionism
# 16             Francisco Goya                              Romanticism
# 17                Frida Kahlo                   Primitivism,Surrealism
# 18                   El Greco                                Mannerism
# 19             Albrecht Dürer                     Northern Renaissance
# 20              Alfred Sisley                            Impressionism
# 21             Pieter Bruegel                     Northern Renaissance
# 22               Marc Chagall                              Primitivism
# 23          Giotto di Bondone                        Proto Renaissance
# 24          Sandro Botticelli                        Early Renaissance
# 25                 Caravaggio                                  Baroque
# 26          Leonardo da Vinci                         High Renaissance
# 27            Diego Velazquez                                  Baroque
# 28              Henri Matisse         Impressionism,Post-Impressionism
# 29               Jan van Eyck                     Northern Renaissance
# 30                Edgar Degas                            Impressionism
# 31                  Rembrandt                                  Baroque
# 32                     Titian               High Renaissance,Mannerism
# 33  Henri de Toulouse-Lautrec                       Post-Impressionism
# 34            Gustave Courbet                                  Realism
# 35           Camille Pissarro         Impressionism,Post-Impressionism
# 36             William Turner                              Romanticism
# 37               Edvard Munch                  Symbolism,Expressionism
# 38               Paul Cezanne                       Post-Impressionism
# 39           Eugene Delacroix                              Romanticism
# 40             Henri Rousseau                              Primitivism
# 41             Georges Seurat                       Post-Impressionism
# 42                  Paul Klee  Expressionism,Abstractionism,Surrealism
# 43              Piet Mondrian                            Neoplasticism
# 44                  Joan Miro                               Surrealism
# 45                Andy Warhol                                  Pop Art
# 46               Paul Gauguin             Symbolism,Post-Impressionism
# 47                    Raphael                         High Renaissance
# 48               Michelangelo                         High Renaissance
# 49            Jackson Pollock                   Abstract Expressionism
#
#                    genre_1             genre_2     genre_3
# 0            Expressionism                None        None
# 1            Expressionism      Abstractionism        None
# 2           Social Realism            Muralism        None
# 3            Impressionism                None        None
# 4               Surrealism       Impressionism        None
# 5               Surrealism                None        None
# 6                  Realism       Impressionism        None
# 7            Byzantine Art                None        None
# 8       Post-Impressionism                None        None
# 9                Symbolism         Art Nouveau        None
# 10    Northern Renaissance                None        None
# 11             Suprematism                None        None
# 12               Symbolism                None        None
# 13                  Cubism                None        None
# 14                 Baroque                None        None
# 15           Impressionism                None        None
# 16             Romanticism                None        None
# 17             Primitivism          Surrealism        None
# 18               Mannerism                None        None
# 19    Northern Renaissance                None        None
# 20           Impressionism                None        None
# 21    Northern Renaissance                None        None
# 22             Primitivism                None        None
# 23       Proto Renaissance                None        None
# 24       Early Renaissance                None        None
# 25                 Baroque                None        None
# 26        High Renaissance                None        None
# 27                 Baroque                None        None
# 28           Impressionism  Post-Impressionism        None
# 29    Northern Renaissance                None        None
# 30           Impressionism                None        None
# 31                 Baroque                None        None
# 32        High Renaissance           Mannerism        None
# 33      Post-Impressionism                None        None
# 34                 Realism                None        None
# 35           Impressionism  Post-Impressionism        None
# 36             Romanticism                None        None
# 37               Symbolism       Expressionism        None
# 38      Post-Impressionism                None        None
# 39             Romanticism                None        None
# 40             Primitivism                None        None
# 41      Post-Impressionism                None        None
# 42           Expressionism      Abstractionism  Surrealism
# 43           Neoplasticism                None        None
# 44              Surrealism                None        None
# 45                 Pop Art                None        None
# 46               Symbolism  Post-Impressionism        None
# 47        High Renaissance                None        None
# 48        High Renaissance                None        None
# 49  Abstract Expressionism                None        None

# %%
artworks_1=artworks_shrunk.drop('genre',1)
artworks_1
# Out:
#                          name                 genre_1             genre_2  \
# 0           Amedeo Modigliani           Expressionism                None
# 1          Vasiliy Kandinskiy           Expressionism      Abstractionism
# 2                Diego Rivera          Social Realism            Muralism
# 3                Claude Monet           Impressionism                None
# 4               Rene Magritte              Surrealism       Impressionism
# 5               Salvador Dali              Surrealism                None
# 6               Edouard Manet                 Realism       Impressionism
# 7               Andrei Rublev           Byzantine Art                None
# 8            Vincent van Gogh      Post-Impressionism                None
# 9                Gustav Klimt               Symbolism         Art Nouveau
# 10           Hieronymus Bosch    Northern Renaissance                None
# 11           Kazimir Malevich             Suprematism                None
# 12             Mikhail Vrubel               Symbolism                None
# 13              Pablo Picasso                  Cubism                None
# 14          Peter Paul Rubens                 Baroque                None
# 15      Pierre-Auguste Renoir           Impressionism                None
# 16             Francisco Goya             Romanticism                None
# 17                Frida Kahlo             Primitivism          Surrealism
# 18                   El Greco               Mannerism                None
# 19             Albrecht Dürer    Northern Renaissance                None
# 20              Alfred Sisley           Impressionism                None
# 21             Pieter Bruegel    Northern Renaissance                None
# 22               Marc Chagall             Primitivism                None
# 23          Giotto di Bondone       Proto Renaissance                None
# 24          Sandro Botticelli       Early Renaissance                None
# 25                 Caravaggio                 Baroque                None
# 26          Leonardo da Vinci        High Renaissance                None
# 27            Diego Velazquez                 Baroque                None
# 28              Henri Matisse           Impressionism  Post-Impressionism
# 29               Jan van Eyck    Northern Renaissance                None
# 30                Edgar Degas           Impressionism                None
# 31                  Rembrandt                 Baroque                None
# 32                     Titian        High Renaissance           Mannerism
# 33  Henri de Toulouse-Lautrec      Post-Impressionism                None
# 34            Gustave Courbet                 Realism                None
# 35           Camille Pissarro           Impressionism  Post-Impressionism
# 36             William Turner             Romanticism                None
# 37               Edvard Munch               Symbolism       Expressionism
# 38               Paul Cezanne      Post-Impressionism                None
# 39           Eugene Delacroix             Romanticism                None
# 40             Henri Rousseau             Primitivism                None
# 41             Georges Seurat      Post-Impressionism                None
# 42                  Paul Klee           Expressionism      Abstractionism
# 43              Piet Mondrian           Neoplasticism                None
# 44                  Joan Miro              Surrealism                None
# 45                Andy Warhol                 Pop Art                None
# 46               Paul Gauguin               Symbolism  Post-Impressionism
# 47                    Raphael        High Renaissance                None
# 48               Michelangelo        High Renaissance                None
# 49            Jackson Pollock  Abstract Expressionism                None
#
#        genre_3
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None
# 10        None
# 11        None
# 12        None
# 13        None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 21        None
# 22        None
# 23        None
# 24        None
# 25        None
# 26        None
# 27        None
# 28        None
# 29        None
# 30        None
# 31        None
# 32        None
# 33        None
# 34        None
# 35        None
# 36        None
# 37        None
# 38        None
# 39        None
# 40        None
# 41        None
# 42  Surrealism
# 43        None
# 44        None
# 45        None
# 46        None
# 47        None
# 48        None
# 49        None

# %%
# Prepare 2nd table 'df'
directory = r"C:\Users\annes\OneDrive\Bureau\data\resized"
data = []
for file in sorted(os.listdir(directory)):
    data.append(file)

# %%
df = pd.DataFrame(columns=['File_complete_name'])
df['File_complete_name']=data
df.head(2)
# Out:
#        File_complete_name
# 0   Albrecht_Dürer_1.jpg
# 1  Albrecht_Dürer_10.jpg

# %%
# new data frame with split value columns 
new=df['File_complete_name'].str.rsplit("_", n = 1,expand= True) 
new_b=new[1].str.rsplit(".", n = 1,expand= True) 

df['artist_name'] = new[0]
df['picture_nb'] = new_b[0]

df['artist_name'] = df['artist_name'].str.replace(r'_', ' ')
df.head(2)
# Out:
#        File_complete_name      artist_name picture_nb
# 0   Albrecht_Dürer_1.jpg  Albrecht Dürer          1
# 1  Albrecht_Dürer_10.jpg  Albrecht Dürer         10

# %%
# Merge the two tables artworks_final and df
df1=df.merge(artworks_1,left_on=df.artist_name, right_on=artworks_1.name)
df1.drop(['key_0','name'],1,inplace=True)
df1.head()
# Out:
#       File_complete_name    artist_name picture_nb        genre_1 genre_2  \
# 0    Alfred_Sisley_1.jpg  Alfred Sisley          1  Impressionism    None
# 1   Alfred_Sisley_10.jpg  Alfred Sisley         10  Impressionism    None
# 2  Alfred_Sisley_100.jpg  Alfred Sisley        100  Impressionism    None
# 3  Alfred_Sisley_101.jpg  Alfred Sisley        101  Impressionism    None
# 4  Alfred_Sisley_102.jpg  Alfred Sisley        102  Impressionism    None
#
#   genre_3
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
df1.shape
# Out:
# (8027, 6)
