# %%
import pandas as pd
import os

# %%
path_to_artists = r'C:\Users\annes\OneDrive\Bureau\data\artists.csv'
path_to_images = r"C:\Users\annes\OneDrive\Bureau\data\resized"

# %%
# on crée les deux dataframes
df_artists = pd.read_csv(path_to_artists, index_col=0)
df_filenames = pd.DataFrame({'filename':[t for t in os.listdir(path_to_images) if 'ipynb' not in t ]})

# %%
# on recrée le nom des artistes dans le dataset filename
df_filenames['artist'] = df_filenames['filename'].apply(lambda f: '_'.join(f.split('_')[:-1]))

# %%
# on crée un dictionnaire qui contient le nom des artistes par ordre alphabetique
ranks = {artist: rank for rank, artist in enumerate(sorted(df_filenames['artist'].unique()))}

# %%
# on crée une colonne rank avec le rang de l'artiste par ordre alphabétique
df_filenames['rank'] = df_filenames['artist'].apply(ranks.get)
df_filenames.head()
# Out:
#                   filename           artist  rank
# 0    Albrecht_Dürer_1.jpg  Albrecht_Dürer     0
# 1   Albrecht_Dürer_10.jpg  Albrecht_Dürer     0
# 2  Albrecht_Dürer_100.jpg  Albrecht_Dürer     0
# 3  Albrecht_Dürer_101.jpg  Albrecht_Dürer     0
# 4  Albrecht_Dürer_102.jpg  Albrecht_Dürer     0

# %%
# crée la même colonne avec le jeu de données sur les artistes
df_artists['rank'] = df_artists['name'].rank().astype(int)-1
df_artists.sort_values('rank').head()
# Out:
#                  name        years                 genre     nationality  \
# id
# 19     Albrecht Dürer  1471 - 1528  Northern Renaissance          German
# 20      Alfred Sisley  1839 - 1899         Impressionism  French,British
# 0   Amedeo Modigliani  1884 - 1920         Expressionism         Italian
# 7       Andrei Rublev  1360 - 1430         Byzantine Art         Russian
# 45        Andy Warhol  1928 – 1987               Pop Art        American
#
#                                                   bio  \
# id
# 19  Albrecht Dürer (; German: [ˈʔalbʁɛçt ˈdyːʁɐ]; ...
# 20  Alfred Sisley (; French: [sislɛ]; 30 October 1...
# 0   Amedeo Clemente Modigliani (Italian pronunciat...
# 7   Andrei Rublev (Russian: Андре́й Рублёв, IPA: [...
# 45  Andy Warhol (; born Andrew Warhola; August 6, ...
#
#                                          wikipedia  paintings  rank
# id
# 19     http://en.wikipedia.org/wiki/Albrecht_Dürer        328     0
# 20      http://en.wikipedia.org/wiki/Alfred_Sisley        259     1
# 0   http://en.wikipedia.org/wiki/Amedeo_Modigliani        193     2
# 7       http://en.wikipedia.org/wiki/Andrei_Rublev         99     3
# 45       https://en.wikipedia.org/wiki/Andy_Warhol        181     4

# %%
# on supprime les colonnes qui ne servent à rien
df_artists = df_artists.drop(labels=['years','nationality','bio','wikipedia','paintings'],axis=1)
# on crée nos colonnes genres
df_artists[['genre_1','genre_2','genre_3']] = df_artists['genre'].str.split(",",expand=True)
df_artists.head()
# Out:
#                   name                         genre  rank         genre_1  \
# id
# 0    Amedeo Modigliani                 Expressionism     2   Expressionism
# 1   Vasiliy Kandinskiy  Expressionism,Abstractionism    47   Expressionism
# 2         Diego Rivera       Social Realism,Muralism     8  Social Realism
# 3         Claude Monet                 Impressionism     7   Impressionism
# 4        Rene Magritte      Surrealism,Impressionism    43      Surrealism
#
#            genre_2 genre_3
# id
# 0             None    None
# 1   Abstractionism    None
